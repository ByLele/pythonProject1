# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import chromedriver_binary  # Adds chromedriver binary to path
from bs4 import BeautifulSoup

# %%
option = webdriver.ChromeOptions()
option.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36')
driver = webdriver.Chrome(options=option)
driver.implicitly_wait(5)
driver.get('https://www.qcc.com/')
driver.maximize_window()

# %%
    text_lable=driver.find_element(By.ID,'searchKey')
    text_lable.clear()
    text_lable.send_keys('宝山钢铁')
    time.sleep(1)
    button=driver.find_element(By.CLASS_NAME,'input-group-btn')#搜索按钮
    button.click()

# %%
def get_result_table(result_html):  #python读表  
    #soup = BeautifulSoup(result_html,'lxml')#
    #x=str(soup.find('table','ntable'))#
    #result_table = pd.read_html(x)[0]#
    
    soup = BeautifulSoup(driver.page_source,'lxml')
    result_table=pd.read_html(str(soup.find('table','ntable')))[0]
    #result_table=pd.read_html(str(soup.find('table','ntable')))[0]

    company_name=result_table[result_table[2]=='企业名称'][3].values[0]
    # print(result_table[2]=='企业名称')
    # print(company_name)
    # print(result_table[2]=='注册资本')
    company_size=result_table[result_table[0]=='人员规模'][1].values[0]
    book_value=result_table[result_table[2]=='注册资本'][3].values[0]
    print(book_value)
    company_type=result_table[result_table[0]=='企业类型'][1].values[0]
    company_field=result_table[result_table[0]=='所属行业'][1].values[0]
    company_area=result_table[result_table[0]=='经营范围'][1].values[0]
    # print(result_table[2][3])
    # print(result_table[1][5])
    print(result_table[4]=='成立日期')
    open_data=result_table[result_table[4]=='成立日期'][5].values[0]
    # open_data=result_table[result_table[0]=='成立日期'][5].values[0]
    columns=['企业名称','人员规模','注册资本','企业类型','所属行业','经营范围','成立日期']
    result=pd.DataFrame([[company_name,company_size,book_value,company_type,company_field,company_area,open_data]],columns)
    return result
    #return result_table

get_result_table(driver.page_source)
# Out:
# 2226841.155万元人民币
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 4, dtype: bool
#                   0         1                 2                3  \
# 企业名称  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
# 人员规模  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
# 注册资本  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
# 企业类型  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
# 所属行业  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
# 经营范围  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
# 成立日期  宝山钢铁股份有限公司 复制  10000人以上  2226841.155万元人民币  股份有限公司（上市、国有控股）
#
#                  4                                                  5  \
# 企业名称  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
# 人员规模  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
# 注册资本  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
# 企业类型  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
# 所属行业  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
# 经营范围  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
# 成立日期  黑色金属冶炼和压延加工业  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
#
#                   6
# 企业名称  2000-02-03 复制
# 人员规模  2000-02-03 复制
# 注册资本  2000-02-03 复制
# 企业类型  2000-02-03 复制
# 所属行业  2000-02-03 复制
# 经营范围  2000-02-03 复制
# 成立日期  2000-02-03 复制

# %%
    try:
        results = driver.find_element(By.XPATH,'//*[@class="maininfo"]/div[1]/span[1]')
        results.click()
        driver.switch_to.window(driver.window_handles[-1])#切换页面
        #print(driver.page_source)#页面html
        result_table=get_result_table(driver.page_source)
        #final_result=final_result.append(result_table)
        #driver.close()
    except:
        print('Error')

# %%
get_result_table(driver.page_source)

# %%
soup = BeautifulSoup(driver.page_source,'lxml')
pd.read_html(str(soup.find('table','ntable')))[0]
# Out:
#           0                                                  1  \
# 0  统一社会信用代码                              91310000631696382C 复制
# 1     法定代表人                                       邹继新 关联3家企业 >
# 2     法定代表人                                       邹继新 关联3家企业 >
# 3    组织机构代码                                      63169638-2 复制
# 4      企业类型                                    股份有限公司（上市、国有控股）
# 5      所属行业                                       黑色金属冶炼和压延加工业
# 6      人员规模                                           10000人以上
# 7       英文名                  Baoshan Iron & Steel Co., Ltd. 复制
# 8      注册地址                              上海市宝山区富锦路885号 附近企业 复制
# 9      经营范围  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
#
#                                                    2  \
# 0                                               企业名称
# 1                                               登记状态
# 2                                               注册资本
# 3                                              工商注册号
# 4                                               营业期限
# 5                                               所属地区
# 6                                               参保人数
# 7                  Baoshan Iron & Steel Co., Ltd. 复制
# 8                              上海市宝山区富锦路885号 附近企业 复制
# 9  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
#
#                                                    3  \
# 0                                      宝山钢铁股份有限公司 复制
# 1                                       存续（在营、开业、在册）
# 2                                   2226841.155万元人民币
# 3                                 310000000074519 复制
# 4                               2000-02-03  至  无固定期限
# 5                                             上海市宝山区
# 6                                     13736 (2021年报)
# 7                  Baoshan Iron & Steel Co., Ltd. 复制
# 8                              上海市宝山区富锦路885号 附近企业 复制
# 9  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
#
#                                                    4  \
# 0                                      宝山钢铁股份有限公司 复制
# 1                                               成立日期
# 2                                               实缴资本
# 3                                             纳税人识别号
# 4                                              纳税人资质
# 5                                               登记机关
# 6                                               核准日期
# 7                                            进出口企业代码
# 8                              上海市宝山区富锦路885号 附近企业 复制
# 9  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...
#
#                                                    5
# 0                                      宝山钢铁股份有限公司 复制
# 1                                      2000-02-03 复制
# 2                                  1647172.4924万元人民币
# 3                              91310000631696382C 复制
# 4                                           增值税一般纳税人
# 5                                         上海市市场监督管理局
# 6                                      2022-09-01 复制
# 7                                   3100631696382 复制
# 8                              上海市宝山区富锦路885号 附近企业 复制
# 9  许可项目：危险化学品生产；危险化学品经营；危险废物经营；发电业务、输电业务、供（配）电业务；...

# %%
soup.find('table','ntable')

# %%
pd.read_html(str(soup.find('table','ntable')))[0]
#x = soup.find('table','ntable')
#print(x)
#pd.read_html(x)[0]
# Out:
#                            0  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  “宝山钢铁” 招投标 99条+ 宝山钢铁 高级查询
# 4                        NaN
# 5                        NaN
#
#                                                    1  \
# 0  宝山钢铁股份有限公司 存续 复制 笔记  关注  央企子公司  A股 | 宝钢股份 6000...
# 1  宝山钢铁股份有限公司 已终止营业地点 复制 笔记  关注  中国香港  董事长：- 股本：-...
# 2  宝山钢铁股份有限公司镀锡板厂 存续 复制 笔记  关注  小微企业  负责人：陆勇 注册资本...
# 3                          “宝山钢铁” 招投标 99条+ 宝山钢铁 高级查询
# 4  山西省代县宝山钢铁有限公司 存续 复制 笔记  关注  小微企业  法定代表人：杨立军 注册...
# 5  宝山钢铁股份有限公司精密钢管厂 存续 复制 笔记  关注  小微企业  负责人：李忆杰 注册...
#
#                            2
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  “宝山钢铁” 招投标 99条+ 宝山钢铁 高级查询
# 4                        NaN
# 5                        NaN

# %%
pd.read_html(x)

# %%
final_result = pd.DataFrame()
#file_list=list(pd.read_excel('企业家白名单.xlsx')['公司名称'])
for file in file_list[39:]:
    driver.switch_to.window(driver.window_handles[-1])
    text_lable=driver.find_element(By.ID,'searchKey')
    text_lable.clear()
    text_lable.send_keys(file)
    time.sleep(1)
    button=driver.find_element(By.CLASS_NAME,'input-grout-btn')
    button.click()
    driver.implicitly_wait(5)
